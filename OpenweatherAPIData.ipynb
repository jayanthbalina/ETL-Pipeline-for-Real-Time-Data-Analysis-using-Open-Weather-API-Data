# %%
pip install requests pandas sqlalchemy psycopg2-binary

# %%
import requests
import pandas as pd

API_KEY = 'your_api_key'  # Replace with your OpenWeatherMap API key
CITY = 'London'
URL = f'http://api.openweathermap.org/data/2.5/weather?q=london&appid=3a2bf9d90794459a5d0f00eb74d48665'

def fetch_weather_data():
    response = requests.get(URL)
    data = response.json()
    return data

weather_data = fetch_weather_data()

# %%
def process_data(data):
    main = data['main']
    weather = {
        'city': data['name'],
        'temperature': main['temp'],
        'pressure': main['pressure'],
        'humidity': main['humidity'],
        'weather_description': data['weather'][0]['description'],
        'timestamp': pd.to_datetime(data['dt'], unit='s')
    }
    return weather

processed_data = process_data(weather_data)
df = pd.DataFrame([processed_data])

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# Database connection parameters
DATABASE_TYPE = 'postgresql'
DBAPI = 'psycopg2'
ENDPOINT = 'localhost'  # Replace with your DB endpoint if different
USER = 'postgres'  # Replace with your PostgreSQL username
PASSWORD = 'Jayanth%4018'  # Replace with your PostgreSQL password
PORT = 5432
DATABASE = 'postgres'

# Create SQLAlchemy engine
engine = create_engine(f"{DATABASE_TYPE}+{DBAPI}://{USER}:{PASSWORD}@{ENDPOINT}:{PORT}/{DATABASE}")

# Load data into PostgreSQL table

df.to_sql('weather_data', engine, if_exists='append', index=False)

print("Data loaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145             try:
# --> 146                 self._dbapi_connection = engine.raw_connection()
#     147             except dialect.loaded_dbapi.Error as err:
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in raw_connection(self)
#    3299         """
# -> 3300         return self.pool.connect()
#    3301
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     448         """
# --> 449         return _ConnectionFairy._checkout(self)
#     450
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#    1262         if not fairy:
# ...
